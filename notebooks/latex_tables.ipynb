# %% [markdown]
# # Dataset analysis

# %% [markdown]
# ## Number of communities over networks and algorithms

# %%
import json
import os

# List of datasets (corresponding to *.json files in current directory)
datasets = ["kar", "words", "vote", "pow", "fb-75", "cond-mat", "fb-artist", "dblp"]

# Order of algorithms to appear in the table
algorithms = ["greedy", "louvain", "leiden", "walktrap", "infomap", 
              "label_propagation", "leading_eigenvector", "edge_betweenness", "spinglass"]

# Algorithm short names for the LaTeX header
alg_short = {
    "greedy": "gre",
    "louvain": "louv",
    "leiden": "leid",
    "walktrap": "walk",
    "infomap": "inf",
    "label_propagation": "lab",
    "leading_eigenvector": "eig",
    "edge_betweenness": "btw",
    "spinglass": "spin"
}

# Start building the LaTeX table
latex = r"""\begin{table}[h!]
\centering
\begin{tabular}{lcc""" + "c" * len(algorithms) + "}\n"

# Header row
header = ["\\textbf{Network}", "$|V|$", "$|E|$"] + [f"\\textbf{{{alg_short[a]}}}" for a in algorithms]
latex += " & ".join(header) + r" \\" + "\n\\hline\n"


data_dir = "../outputs_review/dataset_analysis/"
# Process each dataset
for name in datasets:
    filename = f"{name}.json"
    if not os.path.exists(data_dir+filename):
        print(f"Warning: {filename} not found.")
        continue
    
    with open(data_dir+filename, 'r') as f:
        data = json.load(f)
    
    row = [name, str(data["n_nodes"]), str(data["n_edges"])]
    
    for alg in algorithms:
        alg_data = data["detection_algorithms"].get(alg)
        if alg_data:
            if alg_data["Number of Communities"] == "NA":
                row.append("-")
            else:
                row.append(str(alg_data["Number of Communities"]))
        else:
            row.append("-")
    
    latex += " & ".join(row) + r" \\" + "\n"

# End table
latex += r"""\hline
\end{tabular}
\caption{Number of Communities Detected by Different Algorithms}
\end{table}"""

# Output LaTeX code
print(latex)
# Out:
# \begin{table}[h!]
# \centering
# \begin{tabular}{lccccccccccc}
# \textbf{Network} & $|V|$ & $|E|$ & \textbf{gre} & \textbf{louv} & \textbf{leid} & \textbf{walk} & \textbf{inf} & \textbf{lab} & \textbf{eig} & \textbf{btw} & \textbf{spin} \\
# \hline
# kar & 34 & 78 & 3 & 4 & 4 & 5 & 3 & 2 & 4 & 5 & 4 \\
# words & 112 & 425 & 7 & 7 & 6 & 25 & 2 & 1 & 10 & 69 & 8 \\
# vote & 889 & 2914 & 12 & 9 & 10 & 42 & 75 & 13 & 6 & 16 & 11 \\
# pow & 4941 & 6594 & 41 & 41 & 38 & 364 & 487 & 499 & 130 & 45 & 25 \\
# fb-75 & 6370 & 217654 & 16 & 12 & 13 & 349 & 124 & 12 & 5 & - & 21 \\
# cond-mat & 21363 & 91286 & 270 & 51 & 56 & 2306 & 1335 & 1553 & - & - & 25 \\
# fb-artist & 50515 & 819090 & 281 & 32 & 31 & 2555 & 1529 & 55 & - & - & 25 \\
# dblp & 317080 & 1049866 & 3167 & 212 & 267 & 30425 & 16969 & 20860 & - & - & 25 \\
# \hline
# \end{tabular}
# \caption{Number of Communities Detected by Different Algorithms}
# \end{table}

# %% [markdown]
# ## Modularity of communities across datasets and algorithms

# %%
import json
import os

# List of datasets (corresponding to *.json files in current directory)
datasets = ["kar", "words", "vote", "pow", "fb-75", "cond-mat", "fb-artist", "dblp"]

# Order of algorithms to appear in the table
algorithms = ["greedy", "louvain", "leiden", "walktrap", "infomap", 
              "label_propagation", "leading_eigenvector", "edge_betweenness", "spinglass"]

# Algorithm short names for the LaTeX header
alg_short = {
    "greedy": "gre",
    "louvain": "louv",
    "leiden": "leid",
    "walktrap": "walk",
    "infomap": "inf",
    "label_propagation": "lab",
    "leading_eigenvector": "eig",
    "edge_betweenness": "btw",
    "spinglass": "spin"
}

# Start building the LaTeX table
latex = r"""\begin{table}[h!]
\centering
\begin{tabular}{lcc""" + "c" * len(algorithms) + "}\n"

# Header row
header = ["\\textbf{Network}", "$|V|$", "$|E|$"] + [f"\\textbf{{{alg_short[a]}}}" for a in algorithms]
latex += " & ".join(header) + r" \\" + "\n\\hline\n"


data_dir = "../outputs_review/dataset_analysis/"
# Process each dataset
for name in datasets:
    filename = f"{name}.json"
    if not os.path.exists(data_dir+filename):
        print(f"Warning: {filename} not found.")
        continue
    
    with open(data_dir+filename, 'r') as f:
        data = json.load(f)
    
    row = [name, str(data["n_nodes"]), str(data["n_edges"])]
    
    for alg in algorithms:
        alg_data = data["detection_algorithms"].get(alg)
        if alg_data:
            if "Modularity" not in alg_data or alg_data["Modularity"] == "NA":
                row.append("-")
            else:
                row.append(str(alg_data["Modularity"]))
        else:
            row.append("-")
    
    latex += " & ".join(row) + r" \\" + "\n"

# End table
latex += r"""\hline
\end{tabular}
\caption{Number of Communities Detected by Different Algorithms}
\end{table}"""

# Output LaTeX code
print(latex)
# Out:
# \begin{table}[h!]
# \centering
# \begin{tabular}{lccccccccccc}
# \textbf{Network} & $|V|$ & $|E|$ & \textbf{gre} & \textbf{louv} & \textbf{leid} & \textbf{walk} & \textbf{inf} & \textbf{lab} & \textbf{eig} & \textbf{btw} & \textbf{spin} \\
# \hline
# kar & 34 & 78 & 0.380671 & 0.418803 & 0.41979 & 0.353222 & 0.402038 & 0.371466 & 0.393409 & 0.401298 & 0.41979 \\
# words & 112 & 425 & 0.294696 & 0.293996 & 0.302829 & 0.216213 & 0.009235 & 0.0 & 0.242602 & 0.080537 & 0.310721 \\
# vote & 889 & 2914 & 0.547005 & 0.575221 & 0.594345 & 0.561373 & 0.511637 & 0.5393 & 0.520009 & 0.568533 & 0.598055 \\
# pow & 4941 & 6594 & 0.933511 & 0.935344 & 0.93813 & 0.830962 & 0.816781 & 0.800225 & 0.897732 & 0.933016 & 0.92237 \\
# fb-75 & 6370 & 217654 & 0.380796 & 0.421001 & 0.430282 & 0.38066 & 0.395226 & 0.206766 & 0.393187 & - & 0.430912 \\
# cond-mat & 21363 & 91286 & 0.64441 & 0.726787 & 0.735201 & 0.572629 & 0.63528 & 0.62013 & - & - & 0.723929 \\
# fb-artist & 50515 & 819090 & 0.456295 & 0.593191 & 0.620855 & 0.550986 & 0.546194 & 0.257331 & - & - & 0.599785 \\
# dblp & 317080 & 1049866 & 0.728655 & 0.820835 & 0.830468 & 0.671933 & 0.722575 & 0.676778 & - & - & 0.801035 \\
# \hline
# \end{tabular}
# \caption{Number of Communities Detected by Different Algorithms}
# \end{table}

# %% [markdown]
# ## Runtime across datasets and algorithms

# %%
import json
import os

# List of datasets (corresponding to *.json files in current directory)
datasets = ["kar", "words", "vote", "pow", "fb-75", "cond-mat", "fb-artist", "dblp"]

# Order of algorithms to appear in the table
algorithms = ["greedy", "louvain", "leiden", "walktrap", "infomap", 
              "label_propagation", "leading_eigenvector", "edge_betweenness", "spinglass"]

# Algorithm short names for the LaTeX header
alg_short = {
    "greedy": "gre",
    "louvain": "louv",
    "leiden": "leid",
    "walktrap": "walk",
    "infomap": "inf",
    "label_propagation": "lab",
    "leading_eigenvector": "eig",
    "edge_betweenness": "btw",
    "spinglass": "spin"
}

# Start building the LaTeX table
latex = r"""\begin{table}[h!]
\centering
\begin{tabular}{lcc""" + "c" * len(algorithms) + "}\n"

# Header row
header = ["\\textbf{Network}", "$|V|$", "$|E|$"] + [f"\\textbf{{{alg_short[a]}}}" for a in algorithms]
latex += " & ".join(header) + r" \\" + "\n\\hline\n"


data_dir = "../outputs_review/dataset_analysis/"
# Process each dataset
for name in datasets:
    filename = f"{name}.json"
    if not os.path.exists(data_dir+filename):
        print(f"Warning: {filename} not found.")
        continue
    
    with open(data_dir+filename, 'r') as f:
        data = json.load(f)
    
    row = [name, str(data["n_nodes"]), str(data["n_edges"])]
    
    for alg in algorithms:
        alg_data = data["detection_algorithms"].get(alg)
        if alg_data:
            if "Time" not in alg_data or alg_data["Time"] == "NA":
                row.append("-")
            else:
                row.append(str(alg_data["Time"]))
        else:
            row.append("-")
    
    latex += " & ".join(row) + r" \\" + "\n"

# End table
latex += r"""\hline
\end{tabular}
\caption{Number of Communities Detected by Different Algorithms}
\end{table}"""

# Output LaTeX code
print(latex)
# Out:
# \begin{table}[h!]
# \centering
# \begin{tabular}{lccccccccccc}
# \textbf{Network} & $|V|$ & $|E|$ & \textbf{gre} & \textbf{louv} & \textbf{leid} & \textbf{walk} & \textbf{inf} & \textbf{lab} & \textbf{eig} & \textbf{btw} & \textbf{spin} \\
# \hline
# kar & 34 & 78 & 6.7e-05 & 0.000108 & 0.000769 & 0.00011 & 0.006987 & 0.000102 & 0.002131 & 0.000835 & 0.420321 \\
# words & 112 & 425 & 0.000243 & 0.000366 & 0.003569 & 0.000777 & 0.036574 & 0.000248 & 0.009272 & 0.101571 & 1.993095 \\
# vote & 889 & 2914 & 0.003425 & 0.001988 & 0.016037 & 0.021912 & 0.736294 & 0.003979 & 0.029331 & 27.701101 & 10.40925 \\
# pow & 4941 & 6594 & 0.003531 & 0.008803 & 0.055911 & 0.105511 & 3.567437 & 0.065316 & 3.449903 & 66.356223 & 63.738616 \\
# fb-75 & 6370 & 217654 & 1.157736 & 0.166011 & 0.709276 & 6.603838 & 39.253228 & 0.047521 & 0.504911 & - & 863.840795 \\
# cond-mat & 21363 & 91286 & 1.702693 & 0.106462 & 0.521404 & 10.37659 & 35.6251 & 0.369274 & - & - & 738.199543 \\
# fb-artist & 50515 & 819090 & 122.924262 & 2.129786 & 3.528397 & 304.967463 & 478.170088 & 0.518204 & - & - & 4517.839783 \\
# dblp & 317080 & 1049866 & 409.617816 & 3.367044 & 8.221617 & 1631.181645 & 1913.242572 & 89.478221 & - & - & 12221.033253 \\
# \hline
# \end{tabular}
# \caption{Number of Communities Detected by Different Algorithms}
# \end{table}

# %% [markdown]
# # CMH analysis

# %% [markdown]
# ## Budget used for Nabla-CMH

# %%
import os
import json
import numpy as np


def extract_budgets_for_latex_table(base_path, tau, beta, alg,seeds):
    datasets = ['kar','words','vote', 'pow']
    latex_rows = []

    
    for dataset in datasets:
        for seed in seeds:
            budgets = []
            file_path = os.path.join(base_path, f'seed_{seed}/{dataset}', f'{alg}', f'tau_{tau}', f'betaFactor_{beta}', 'json_results/nabla-cmh.json')
            with open(file_path, 'r') as file:
                data = json.load(file)
            
            budget = np.mean([data["steps"][i] for i in range(len(data["goal"])) if data["goal"][i] == 1])
            budgets.append(budget)
            total_budget = data["budget"]
        
        percentage_diff = (np.mean(budgets) / total_budget) * 100
        row_values = [f'${total_budget}$', f'${budget:.1f} ({percentage_diff:.1f}\\%)$']
        
        latex_rows.append(' & '.join(row_values) + ' \\\\')

    return '\n'.join(latex_rows)

tau = 0.5
beta = 1
alg = 'greedy'
base_path = f'../outputs_review/runs/'
seeds=[22,2025,42]
latex_table = extract_budgets_for_latex_table(base_path, tau,beta,alg,seeds)
print(latex_table)
# Out:
# $3$ & $2.4 (79.3\%)$ \\
# $3$ & $1.7 (56.8\%)$ \\
# $3$ & $2.1 (70.9\%)$ \\
# $2$ & $1.9 (92.9\%)$ \\

# %% [markdown]
# ## Time comparison between Nabla-CMH and DRL-Agent

# %%
import os
import json
import numpy as np


def extract_budgets_for_latex_table(base_path, tau, beta, alg,seeds):
    datasets = ['kar','words','vote', 'pow', 'fb-75', 'cond-mat']
    latex_rows = []

    
    for dataset in datasets:
        for seed in seeds:
            times_nabla = []
            times_agent = []
            file_path_nabla = os.path.join(base_path, f'seed_{seed}/{dataset}', f'{alg}', f'tau_{tau}', f'betaFactor_{beta}', 'json_results/nabla-cmh.json')
            with open(file_path_nabla, 'r') as file:
                data_nabla = json.load(file)
            file_path_agent = os.path.join(base_path, f'seed_{seed}/{dataset}', f'{alg}', f'tau_{tau}', f'betaFactor_{beta}', 'json_results/drl-agent.json')
            with open(file_path_agent, 'r') as file:
                data_agent = json.load(file)
            
            time_nabla = np.mean([data_nabla["time"]])
            time_agent = np.mean([data_agent["time"]])
            times_nabla.append(time_nabla)
            times_agent.append(time_agent)
            
        speedup = np.mean(times_agent) / np.mean(times_nabla)
        row_values = [f'${np.mean(times_nabla):.3f}$', f'${np.mean(times_agent):.3f}$', f'$\\times {speedup:.3f} \\blacktriangle$']
        latex_rows.append(' & '.join(row_values) + ' \\\\')
        

    return '\n'.join(latex_rows)

tau = 0.5
beta = 1
alg = 'greedy'
base_path = f'../outputs_review/runs/'
seeds=[22,2025]
latex_table = extract_budgets_for_latex_table(base_path, tau,beta,alg,seeds)
print(latex_table)
# Out:
# $0.015$ & $0.030$ & $\times 1.958 \blacktriangle$ \\
# $0.023$ & $0.051$ & $\times 2.188 \blacktriangle$ \\
# $0.068$ & $0.183$ & $\times 2.675 \blacktriangle$ \\
# $0.114$ & $0.220$ & $\times 1.934 \blacktriangle$ \\
# $21.075$ & $107.644$ & $\times 5.108 \blacktriangle$ \\
# $3.270$ & $5.188$ & $\times 1.587 \blacktriangle$ \\

# %% [markdown]
# ## Percentage of additions/deletions for method

# %%
import json
import os
import pandas as pd

# List of datasets (corresponding to *.json files in current directory)
datasets = ["kar", "words", "vote", "pow", "fb-75", "cond-mat"]

# Order of algorithms to appear in the table
algorithms = ["random", "betweenness", "degree", "nabla-cmh", "dice", "drl-agent", "roam"]

# Process each dataset
for name in datasets:
    print(f"----- Processing dataset: {name} -----")
    data_dir = f"../outputs_review/runs/seed_22/{name}/greedy/tau_0.5/betaFactor_1/json_results/"
    results = pd.DataFrame(columns=["Algorithm", "Percentage Additions", "Percentage Deletions"])
    for alg in algorithms:

        filename = f"{alg}.json"
        if not os.path.exists(data_dir+filename):
            print(f"Warning: {data_dir+filename} not found.")
            break
    
        with open(data_dir+filename, 'r') as f:
            data = json.load(f)
        
        changes = data["changes"]
        n_additions = 0
        n_deletions = 0
        for dict in changes:
            if alg != "nabla-cmh":
                if len(dict["remove"]) > 0:
                    n_deletions += len(dict["remove"])
                if len(dict["add"]) > 0:
                    n_additions += len(dict["add"])
            else:
                if "removed" in dict and len(dict["removed"]) > 0:
                    n_deletions += len(dict["removed"])
                elif "remove" in dict and len(dict["remove"]) > 0:
                    n_deletions += len(dict["remove"])
                elif "added" in dict and len(dict["added"]) > 0:
                    n_additions += len(dict["added"])
                elif "add" in dict and len(dict["add"]) > 0:    
                    n_additions += len(dict["add"])

        percentage_n_additions = (n_additions / (n_additions+n_deletions)) * 100
        percentage_n_deletions = (n_deletions / (n_additions+n_deletions)) * 100

        # Append the data to the dataframe
        results = results.append({
            "Algorithm": alg,
            "Percentage Additions": percentage_n_additions,
            "Percentage Deletions": percentage_n_deletions
        }, ignore_index=True)

    print(results)
# Out:
# ----- Processing dataset: kar -----
#      Algorithm  Percentage Additions  Percentage Deletions
# 0       random             77.450980             22.549020
# 1  betweenness             53.921569             46.078431
# 2       degree             53.921569             46.078431
# 3    nabla-cmh             66.666667             33.333333
# 4         dice             66.666667             33.333333
# 5    drl-agent             88.235294             11.764706
# 6         roam             43.333333             56.666667
# ----- Processing dataset: words -----
#      Algorithm  Percentage Additions  Percentage Deletions
# 0       random             85.365854             14.634146
# 1  betweenness             66.666667             33.333333
# 2       degree             66.666667             33.333333
# 3    nabla-cmh             95.238095              4.761905
# 4         dice             66.666667             33.333333
# 5    drl-agent             96.747967              3.252033
# 6         roam             59.000000             41.000000
# ----- Processing dataset: vote -----
#      Algorithm  Percentage Additions  Percentage Deletions
# 0       random            100.000000              0.000000
# 1  betweenness             84.753363             15.246637
# 2       degree             84.902840             15.097160
# 3    nabla-cmh             98.611111              1.388889
# 4         dice             66.666667             33.333333
# 5    drl-agent             99.551570              0.448430
# 6         roam             58.161351             41.838649
# ----- Processing dataset: pow -----
#      Algorithm  Percentage Additions  Percentage Deletions
# 0       random            100.000000              0.000000
# 1  betweenness            100.000000              0.000000
# 2       degree             98.084291              1.915709
# 3    nabla-cmh            100.000000              0.000000
# 4         dice             50.000000             50.000000
# 5    drl-agent            100.000000              0.000000
# 6         roam             38.443396             61.556604
# ----- Processing dataset: fb-75 -----
#      Algorithm  Percentage Additions  Percentage Deletions
# 0       random             99.323529              0.676471
# 1  betweenness             96.725490              3.274510
# 2       degree             96.803922              3.196078
# 3    nabla-cmh             98.813722              1.186278
# 4         dice             97.058824              2.941176
# 5    drl-agent             99.294118              0.705882
# 6         roam             94.468007              5.531993
# ----- Processing dataset: cond-mat -----
#      Algorithm  Percentage Additions  Percentage Deletions
# 0       random            100.000000              0.000000
# 1  betweenness             99.666667              0.333333
# 2       degree             99.833333              0.166667
# 3    nabla-cmh            100.000000              0.000000
# 4         dice             75.000000             25.000000
# 5    drl-agent             99.916667              0.083333
# 6         roam             48.892675             51.107325

# %% [markdown]
# ## Parameter sensitivity

# %%
import numpy as np

def extract_values_for_latex_params_sensitivity(base_path):
    latex_rows = []
    for tau in taus:
        for beta in betas:
            row_values = [f'tau_{tau} & beta_{beta}']
            for method in methods:
                f1_scores = []
                for seed in seeds:
                    file_path = os.path.join(base_path, f'seed_{seed}', dataset, alg, f'tau_{tau}',f'betaFactor_{beta}', 'plots/metrics.json')
                    with open(file_path, 'r') as file:
                        data = json.load(file)
                    f1_score = data["f1"][method]
                    f1_scores.append(f1_score)
                
                row_values.append(f'${np.mean(f1_scores):.2f} \\pm {np.std(f1_scores):.2f}$')
            latex_rows.append(' & '.join(row_values) + ' \\\\')

    return '\n'.join(latex_rows)

taus = [0.3,0.5,0.8]
betas = [0.5, 1, 2]
methods = ["NABLA", "DRL", "DICE", "RAND"]
dataset = 'vote'
alg = 'greedy'
seeds = [22, 2025, 42]
base_path = f'../outputs_review/runs/'
latex_table = extract_values_for_latex_params_sensitivity(base_path)
print(latex_table)
# Out:
# tau_0.3 & beta_0.5 & $0.72 \pm 0.01$ & $0.45 \pm 0.01$ & $0.62 \pm 0.01$ & $0.42 \pm 0.02$ \\
# tau_0.3 & beta_1 & $0.77 \pm 0.02$ & $0.56 \pm 0.01$ & $0.65 \pm 0.01$ & $0.57 \pm 0.05$ \\
# tau_0.3 & beta_2 & $0.85 \pm 0.03$ & $0.64 \pm 0.01$ & $0.71 \pm 0.01$ & $0.53 \pm 0.01$ \\
# tau_0.5 & beta_0.5 & $0.77 \pm 0.00$ & $0.57 \pm 0.01$ & $0.63 \pm 0.00$ & $0.54 \pm 0.08$ \\
# tau_0.5 & beta_1 & $0.79 \pm 0.01$ & $0.65 \pm 0.00$ & $0.68 \pm 0.01$ & $0.64 \pm 0.04$ \\
# tau_0.5 & beta_2 & $0.85 \pm 0.03$ & $0.72 \pm 0.01$ & $0.80 \pm 0.01$ & $0.64 \pm 0.04$ \\
# tau_0.8 & beta_0.5 & $0.83 \pm 0.01$ & $0.75 \pm 0.02$ & $0.75 \pm 0.01$ & $0.71 \pm 0.04$ \\
# tau_0.8 & beta_1 & $0.86 \pm 0.01$ & $0.80 \pm 0.01$ & $0.82 \pm 0.00$ & $0.80 \pm 0.00$ \\
# tau_0.8 & beta_2 & $0.90 \pm 0.04$ & $0.78 \pm 0.01$ & $0.82 \pm 0.00$ & $0.76 \pm 0.01$ \\
